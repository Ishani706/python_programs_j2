# %% [markdown]
# # conditional statements in python
# 1. python have 4 types of statements
# 2. ``if` statement
# 3. `elif` statement
# 4. `else` satement
# 5. `nested` statement
#
#
# ```python syntax-if
# if( condition): if condition is true then execute or run ststements inside of block
#    statement1
#    ststement2...
# ```
#
# ```python-if ,else
# if(condition):
#    statement1
#    statement2...
# else:
#    statement1
#    statement2
# ```
#
# ```python- if,elif,else
# if (condition ):
#    statement1..n
# elif (condition2) :
#    statement1..n
# elif (condition3):
#    statement1..n
#
#    else:
#    statement1..n

# %%
# write a program to find the given number is odd?
number=int(input("please enter number here:"))
if(number%2 == 1):
    print ( number,"is odd number")
# Out:
# please enter number here: 120

# %%
1001%2
# Out:
# 1

# %%
# write a program to find the given number is even or odd?
num=int(input("please enter number here:"))

if( number%2==0):
   print (num,"is even number")
else:
   print ( num,"is odd number")
# Out:
# please enter number here: 123
# 123 is odd number

# %%
# write a program to find the given number is positive or negative or zero?
n =int(input("please enter number here"))
if (n>0):
  print (n," is positive number")
elif (n<0):
  print ( n,"is negative number") 
else:
  print(n,"is zero")
# Out:
# please enter number here 0
# 0 is zero

# %%
"""
write aprogram to find the grades based on marks 
1. if marks in between 80-100 -grade is A
2. if marks in between 60-79 -grade is B 
3. if marks in betwwen 40-59 -grade is C 
4. if marks in between 25-39 -grade is D 
5. if marks in between 0-29 -grade is Fail
6. if marks is other than above output is- please enter correct marks 
"""
marks=int(input("please enter marks here:"))
if(marks>=80 and marks<=100):
    print(marks,"grade is A")
elif (marks>=60 and marks<=79):
    print( marks,"garde is B")
elif (marks>=40 and marks<59):
   print( marks,"grade is C")
elif (marks>=25 and marks<=39) :
    print( marks,"garde is D")
elif (marks>=0 and marks<=24):
    print(marks,"grade is fail")
else:
    print("please enter correct marks")
# Out:
# please enter marks here: 48
# 48 grade is C

# %%
# write a program to find the largest number fron three numbers?
n1=int(input(" enter first number here:"))
n2=int(input("enter second number here:"))
n3=int(input("enter third number here:"))
if(n1>=n2 and n1>=n3):
    print(n1,"is largest number")
elif(n2>=n1 and n2>=n3):
    print(n2,"is largest number")
else:
    print(n3,"is largest number")
# Out:
#  enter first number here: 3435
# enter second number here: 3673
# enter third number here: 2747
# 3673 is largest number

# %%
# write a program to voilate login credentials using conditional statements?
username=str(input("please enter username here:"))
if (username=="tia@123"):
      print("username is valid")
      password=str(input("please enter user password here:"))
      if(password=="tia@12345"):
         print("user details are successfully validated, thank you!")
      else:
           print("password is wrong")
else:
      print("username is inavalid")
# Out:
# please enter username here: tia@123
# username is valid
# please enter user password here: hiii
# password is wrong

# %%
"""
write a program to find theeven number with number of digits
1. if number in between 1 to 9 then output is -1 digit even number
2. if number in between 10 to 99 then output is -2 digit even number 
3. if number in between 100 to 999 then output is -3 didgit even number
4. if number in between 1000 to 9999 then output is -4 digit even number
5. if another number is above range then output is - weired even number
""" 
num=int(input("please enter number here"))
if(num%2 == 0):
   if (num>=1 and num<=9):
      print(num,"1 digit even number")
   elif (num>=10 and num<=99):
       print(num,"2 digit even number")
   elif (num>=100 and num<=999):
       print( num,"3 digit even number")
   elif (num>=1000 and num<=9999):
       print(num,"4 digit even number")|
   else:
       print("weried even number")
else:
    print(num,"is not even number")
# Out:
#   Cell In[45], line 18
#     print(num,"4 digit even number")|
#                                      ^
# SyntaxError: invalid syntax
