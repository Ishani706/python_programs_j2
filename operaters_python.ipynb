# %% [markdown]
# # operaters in python
#
# ## 6 types of operaters in python
# 1. arithematic operators
# 2. assignment  operators
# 3. comaprison  operators
# 4. logical  operators
# 5. membership  operators
# 6. identity  operators

# %%
# arithemetic operators-+,*,-,/,//,%
a=10
b=20
c=20
d=40
print(a+b)
print(b-c)
print(b*d)
print(d/a)
print(d%a)
# Out:
# 30
# 0
# 800
# 4.0
# 0

# %%
# assignment operators -+=,-=,*=,/=,//=,%=
a=100
a+=50
print(a)
# Out:
# 150

# %%
b=200
b=-400
print(b)
# Out:
# -400

# %%
c=50
c*=100
print(c)
# Out:
# 5000

# %%
# comparison  operators->,<,>=,<=,==,!=
a=10
b=20
c=20
d=30
print(a>b)
print(b==c)
print(b<c)
print(b!=c)
print(b>=a)
print(b<=a)

# %%
# logical operator -and,or,not
"""
and- both conditions are true then result is true,rest case is false
or- either one condition is true the result is true,rest case  result is false
and truth table
T T=T
T F=F
F T=F
F F=F
or truth table
T T=T
T F=T
F T=T
F F=F 
"""

a=10
b=20
c=20
d=30
print(a>b and b==c)
print(a<c and c==b)
print(a>b or b==c)
print( not a>b and b==c)
# Out:
# False
# True
# True
# True

# %%
# membership operator
# volidating members are present in that sequence or group
names=["eshal, panjwani"]
print("eshal" in names)
print("panjwani" not in names)
print("Eshal" not in names)
print ("rahul"in names)
# Out:
# False
# True
# True
# False

# %%
# identity operators -is,is not
a=10000
b=10000
print(a is b)
print(id(a))
print(id(b))
# Out:
# False
# 2873053776848
# 2873053779728

# %%
a=10
b=10
print(a is b)
print(id(a))
print(id(b))
# Out:
# True
# 140723692336328
# 140723692336328
